# %%
import pandas as pd

from model.scenarios import globalParams, params, strategies
from model.engine import analyze_status_quo, run_all_strategies

# %%
status_quo_rele = analyze_status_quo(globalParams, params, strategy="RELE", plot=True)
status_quo_rele

# %%
test_global = globalParams.copy()
test_global["N_Sim"] = 10000  # lighter test

results_test, summary_test = run_all_strategies(test_global, params, strategies)

summary_test
